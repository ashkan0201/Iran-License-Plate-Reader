# %%
import glob
import os
import random
import matplotlib.pyplot as plt

background = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/archive/Raw_Plate/raw_plate.png")

list_of_directory = glob.glob("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/*")

for i in 

overlay1 = plt.imread()
overlay2 = plt.imread()
overlay3 = plt.imread()
overlay4 = plt.imread()
overlay5 = plt.imread()
overlay6 = plt.imread()
overlay7 = plt.imread()
overlay8 = plt.imread()

for i in
# Out:
#   Cell In[14], line 17
#     for i in
#              ^
# SyntaxError: invalid syntax

# %%
list_of_directory = glob.glob("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/*")

# %%
for i in list_of_directory:
    if type(i[-1]) != int:
        images = glob.glob(i+"/*")
        print(images)
#         for j in images:
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Out:
# ['/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/D',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/8',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/Y',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/A',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/Taxi',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/V',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/M',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/G',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/1',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/T',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/E',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/7',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/J',
#  '/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/B',
# ...

# %%
import matplotlib.pyplot as plt

background = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/archive/Raw_Plate/raw_plate.png")
overlay1 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/8/1085_236019.jpg")
overlay2 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/5/5_33357.jpg")
overlay3 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/B/B (11).jpg")
overlay4 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/9/769.jpg")
overlay5 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/2/2_5829.jpg")
overlay6 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/4/4_51712.jpg")
overlay7 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/1/1_48758.jpg")
overlay8 = plt.imread("/home/ashkan/Desktop/Github/Iran-License-Plate-Reader/chars/0/0 (1607).jpg")

# %%
background.shape
# Out:
# (325, 1511, 4)

# %%
plt.imshow(background[0:325,0:140])

# %%
plt.imshow(background)

plt.imshow(overlay1, extent=(150, 315, 310, 20))
plt.imshow(overlay2, extent=(330, 495, 310, 20))
plt.imshow(overlay3, extent=(510, 695, 280, 60))
plt.imshow(overlay4, extent=(710, 875, 310, 20))
plt.imshow(overlay5, extent=(890, 1055, 310, 20))
plt.imshow(overlay6, extent=(1070, 1190, 310, 20))
plt.imshow(overlay7, extent=(1210, 1360, 310, 80))
plt.imshow(overlay8, extent=(1380, 1500, 310, 80))
plt.xlim(0, background.shape[1])
plt.ylim(background.shape[0], 0)

plt.show()

# %%
1511-1210
# Out:
# 301

# %%
1210+150
# Out:
# 1360
